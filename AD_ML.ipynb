# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path = os.getcwd()
file = path + "\youtube .csv"
file
# Out:
# 'C:\\Users\\Meghana\\AD 1\\youtube .csv'

# %%
df = pd.read_csv("youtube .csv")
df
# Out:
#      rank                    Youtuber  subscribers   video_views  \
# 0       1                    T-Series    245000000  228000000000
# 1       2              YouTube Movies    170000000             0
# 2       3                     MrBeast    166000000   28368841870
# 3       4  Cocomelon - Nursery Rhymes    162000000  164000000000
# 4       5                   SET India    159000000  148000000000
# ..    ...                         ...          ...           ...
# 990   991                Natan por A�     12300000    9029609749
# 991   992    Free Fire India Official     12300000    1674409945
# 992   993                       Panda     12300000    2214684303
# 993   994                 RobTopGames     12300000     374123483
# 994   995                Make Joke Of     12300000    2129773714
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video_views  \
# 0     1                    T-Series    245000000  228000000000
# 1     2              YouTube Movies    170000000             0
# 2     3                     MrBeast    166000000   28368841870
# 3     4  Cocomelon - Nursery Rhymes    162000000  164000000000
# 4     5                   SET India    159000000  148000000000
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#     channel_type  video_views_for_the_last_30_days  lowest_monthly_earnings  \
# ...

# %%
df.tail()
# Out:
#      rank                  Youtuber  subscribers  video_views        category  \
# 990   991              Natan por A�     12300000   9029609749          Sports
# 991   992  Free Fire India Official     12300000   1674409945  People & Blogs
# 992   993                     Panda     12300000   2214684303          others
# 993   994               RobTopGames     12300000    374123483          Gaming
# 994   995              Make Joke Of     12300000   2129773714          Comedy
#
#                         Title  uploads         Country   channel_type  \
# 990              Natan por A�     1200          Brazil  Entertainment
# 991  Free Fire India Official     1500           India          Games
# 992               HybridPanda     2452  United Kingdom          Games
# 993               RobTopGames       39          Sweden          Games
# 994              Make Joke Of       62           India         Comedy
#
#      video_views_for_the_last_30_days  lowest_monthly_earnings  \
# ...

# %%
df.shape
# Out:
# (995, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   rank                              995 non-null    int64
#  1   Youtuber                          995 non-null    object
#  2   subscribers                       995 non-null    int64
#  3   video_views                       995 non-null    int64
#  4   category                          995 non-null    object
#  5   Title                             995 non-null    object
#  6   uploads                           995 non-null    int64
#  7   Country                           995 non-null    object
#  8   channel_type                      995 non-null    object
#  9   video_views_for_the_last_30_days  995 non-null    int64
#  10  lowest_monthly_earnings           995 non-null    int64
#  11  highest_monthly_earnings          995 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video_views', 'category', 'Title',
#        'uploads', 'Country', 'channel_type',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# rank                              995.0  4.980000e+02  2.873761e+02
# subscribers                       995.0  2.298241e+07  1.752611e+07
# video_views                       995.0  1.103954e+10  1.411084e+10
# uploads                           995.0  9.187126e+03  3.415135e+04
# video_views_for_the_last_30_days  995.0  1.657267e+08  4.065010e+08
# lowest_monthly_earnings           995.0  3.688615e+04  7.185872e+04
# highest_monthly_earnings          995.0  5.898078e+05  1.148622e+06
# lowest_yearly_earnings            995.0  4.422574e+05  8.612161e+05
# highest_yearly_earnings           995.0  7.081814e+06  1.379704e+07
# subscribers_for_last_30_days      995.0  2.308483e+05  5.261092e+05
#
#                                          min           25%           50%  \
# rank                                     1.0  2.495000e+02  4.980000e+02
# ...

# %%
df.isnull().sum()
# Out:
# rank                                0
# Youtuber                            0
# subscribers                         0
# video_views                         0
# category                            0
# Title                               0
# uploads                             0
# Country                             0
# channel_type                        0
# video_views_for_the_last_30_days    0
# lowest_monthly_earnings             0
# highest_monthly_earnings            0
# lowest_yearly_earnings              0
# highest_yearly_earnings             0
# subscribers_for_last_30_days        0
# dtype: int64

# %%
df[df.duplicated(keep=False)].shape
# Out:
# (0, 15)

# %%
#count plot

# Select only numeric type of columns by their names as:
df1 = df[['video_views','uploads','video_views_for_the_last_30_days','lowest_monthly_earnings','highest_monthly_earnings','lowest_yearly_earnings','highest_yearly_earnings','subscribers_for_last_30_days']]
df1

# Create subplots for the histograms
plt.figure(figsize=(12, 16))

for i, var in enumerate(df1, 1):
    plt.subplot(4, 2, i)
    sns.countplot(x=df[var], palette="Set1")
    plt.title(f'Histogram of {var}')
    plt.xlabel(var)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
df1 = df[['video_views','uploads','video_views_for_the_last_30_days','lowest_monthly_earnings','highest_monthly_earnings','lowest_yearly_earnings','highest_yearly_earnings','subscribers_for_last_30_days']]
df1

# Create subplots for the histograms
plt.figure(figsize=(12, 18))

for i, var in enumerate(df1, 1):
    plt.subplot(4, 2, i)
#     sns.regplot(x=df[var], y='Outcome', data=df)
    plt.scatter(df[var], df['subscribers'], c='blue', marker='o', label='Random Data')
    plt.title(f'Scatter Plot - {var}')
    plt.xlabel(var)
    plt.ylabel('subscribers')

plt.tight_layout()
plt.show()

# %%
df.corr(method='pearson')
# Out:
#                                       rank  subscribers  video_views  \
# rank                              1.000000    -0.640608    -0.453363
# subscribers                      -0.640608     1.000000     0.750958
# video_views                      -0.453363     0.750958     1.000000
# uploads                          -0.051036     0.077136     0.165928
# video_views_for_the_last_30_days -0.178444     0.268556     0.364076
# lowest_monthly_earnings          -0.248394     0.388941     0.552096
# highest_monthly_earnings         -0.248050     0.388579     0.551455
# lowest_yearly_earnings           -0.248593     0.389072     0.552776
# highest_yearly_earnings          -0.248392     0.388935     0.552091
# subscribers_for_last_30_days     -0.191666     0.273450     0.210308
#
#                                    uploads  video_views_for_the_last_30_days  \
# rank                             -0.051036                         -0.178444
# ...

# %%
correlation_matrix = df.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
sorted_corr_msrp = correlation_matrix['subscribers'].sort_values(ascending=False)
sorted_corr_msrp
# Out:
# subscribers                         1.000000
# video_views                         0.750958
# lowest_yearly_earnings              0.389072
# lowest_monthly_earnings             0.388941
# highest_yearly_earnings             0.388935
# highest_monthly_earnings            0.388579
# subscribers_for_last_30_days        0.273450
# video_views_for_the_last_30_days    0.268556
# uploads                             0.077136
# rank                               -0.640608
# Name: subscribers, dtype: float64

# %%
df1 = df[['video_views','uploads','video_views_for_the_last_30_days','lowest_monthly_earnings','highest_monthly_earnings','lowest_yearly_earnings','highest_yearly_earnings','subscribers_for_last_30_days']]
df1

# Create subplots for the histograms
plt.figure(figsize=(12, 15))

for i, var in enumerate(df1, 1):
    plt.subplot(4, 2, i)
    sns.histplot(df[var], bins=20, kde=True)
    plt.title(f'Histogram of {var}')
    plt.xlabel(var)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
df1 = df[['video_views','uploads','video_views_for_the_last_30_days','lowest_monthly_earnings','highest_monthly_earnings','lowest_yearly_earnings','highest_yearly_earnings','subscribers_for_last_30_days']]
df1

# Create subplots for Box Plots
plt.figure(figsize=(12, 15))

for i, var in enumerate(df1, 1):
    plt.subplot(4, 2, i)
    sns.boxplot(y=var, data=df)
    plt.title(f'Box Plot of {var}')

plt.tight_layout()
plt.show()

# %%
#subscribers

Q1 = np.percentile(df.subscribers, 25)
Q3 = np.percentile(df.subscribers, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.subscribers < lower_bound) | (df.subscribers > upper_bound)]
outliers
# Out:
#     rank                                       Youtuber  subscribers  \
# 0      1                                       T-Series    245000000
# 1      2                                 YouTube Movies    170000000
# 2      3                                        MrBeast    166000000
# 3      4                     Cocomelon - Nursery Rhymes    162000000
# 4      5                                      SET India    159000000
# ..   ...                                            ...          ...
# 71    72                                Kimberly Loaiza     41300000
# 72    73  Little Baby Bum - Nursery Rhymes & Kids Songs     40900000
# 73    74                               Luisito Comunica     40600000
# 74    75                                    elrubiusOMG     40400000
# 75    76                                Toys and Colors     40300000
#
#      video_views          category  \
# 0   228000000000             Music
# 1              0  Film & Animation
# ...

# %%
print(f"Lower bound: {lower_bound}")
print(f"Upper bound: {upper_bound}")
# Out:
# Lower bound: -650000.0
# Upper bound: 39750000.0

# %%
def cap_outliers(data, lower_threshold, upper_threshold):
    capped_data = np.clip(data, lower_threshold, upper_threshold)
    return capped_data

# Cap the outliers
capped_data = cap_outliers(df.subscribers, lower_bound, upper_bound)
capped_data

df.loc[:,'subscribers'] = capped_data

# %%
Q1 = np.percentile(df.subscribers, 25)
Q3 = np.percentile(df.subscribers, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.subscribers < lower_bound) | (df.subscribers > upper_bound)]
outliers
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video_views, category, Title, uploads, Country, channel_type, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days]
# Index: []

# %%
#video_views
Q1 = np.percentile(df.video_views, 25)
Q3 = np.percentile(df.video_views, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.video_views < lower_bound) | (df.video_views > upper_bound)]
outliers
# Out:
#      rank                                           Youtuber  subscribers  \
# 0       1                                           T-Series   39750000.0
# 2       3                                            MrBeast   39750000.0
# 3       4                         Cocomelon - Nursery Rhymes   39750000.0
# 4       5                                          SET India   39750000.0
# 6       7                                ��� Kids Diana Show   39750000.0
# 7       8                                          PewDiePie   39750000.0
# 8       9                                        Like Nastya   39750000.0
# 9      10                                      Vlad and Niki   39750000.0
# 10     11                                  Zee Music Company   39750000.0
# 11     12                                                WWE   39750000.0
# 13     14                                          BLACKPINK   39750000.0
# 15     16                                           Sony SAB   39750000.0
# ...

# %%
print(f"Lower bound: {lower_bound}")
print(f"Upper bound: {upper_bound}")
# Out:
# Lower bound: -9611689254.5
# Upper bound: 27454536517.5

# %%
def cap_outliers(data, lower_threshold, upper_threshold):
    capped_data = np.clip(data, lower_threshold, upper_threshold)
    return capped_data

# Cap the outliers
capped_data = cap_outliers(df.video_views, lower_bound, upper_bound)
capped_data

df.loc[:,'video_views'] = capped_data

# %%
Q1 = np.percentile(df.video_views, 25)
Q3 = np.percentile(df.video_views, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.video_views < lower_bound) | (df.video_views > upper_bound)]
outliers
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video_views, category, Title, uploads, Country, channel_type, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days]
# Index: []

# %%
#lowest_yearly_earnings

Q1 = np.percentile(df.lowest_yearly_earnings, 25)
Q3 = np.percentile(df.lowest_yearly_earnings, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.lowest_yearly_earnings < lower_bound) | (df.lowest_yearly_earnings > upper_bound)]
outliers
# Out:
#      rank                    Youtuber  subscribers   video_views  \
# 0       1                    T-Series   39750000.0  2.745454e+10
# 2       3                     MrBeast   39750000.0  2.745454e+10
# 3       4  Cocomelon - Nursery Rhymes   39750000.0  2.745454e+10
# 4       5                   SET India   39750000.0  2.745454e+10
# 6       7         ��� Kids Diana Show   39750000.0  2.745454e+10
# ..    ...                         ...          ...           ...
# 858   859              Peet Montzingo   13400000.0  1.002256e+10
# 905   906                        GH'S   13000000.0  8.739175e+09
# 908   909                 Susy Mouriz   13000000.0  6.270909e+09
# 970   971                    _vector_   12400000.0  7.597013e+09
# 990   991                Natan por A�   12300000.0  9.029610e+09
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# ...

# %%
print(f"Lower bound: {lower_bound}")
print(f"Upper bound: {upper_bound}")
# Out:
# Lower bound: -601025.0
# Upper bound: 1088775.0

# %%
def cap_outliers(data, lower_threshold, upper_threshold):
    capped_data = np.clip(data, lower_threshold, upper_threshold)
    return capped_data

# Cap the outliers
capped_data = cap_outliers(df.lowest_yearly_earnings, lower_bound, upper_bound)
capped_data

df.loc[:,'lowest_yearly_earnings'] = capped_data

# %%
Q1 = np.percentile(df.lowest_yearly_earnings, 25)
Q3 = np.percentile(df.lowest_yearly_earnings, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.lowest_yearly_earnings < lower_bound) | (df.lowest_yearly_earnings > upper_bound)]
outliers
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video_views, category, Title, uploads, Country, channel_type, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days]
# Index: []

# %%
#lowest_monthly_earnings

Q1 = np.percentile(df.lowest_monthly_earnings, 25)
Q3 = np.percentile(df.lowest_monthly_earnings, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.lowest_monthly_earnings < lower_bound) | (df.lowest_monthly_earnings > upper_bound)]
outliers
# Out:
#      rank                    Youtuber  subscribers   video_views  \
# 0       1                    T-Series   39750000.0  2.745454e+10
# 2       3                     MrBeast   39750000.0  2.745454e+10
# 3       4  Cocomelon - Nursery Rhymes   39750000.0  2.745454e+10
# 4       5                   SET India   39750000.0  2.745454e+10
# 6       7         ��� Kids Diana Show   39750000.0  2.745454e+10
# ..    ...                         ...          ...           ...
# 858   859              Peet Montzingo   13400000.0  1.002256e+10
# 905   906                        GH'S   13000000.0  8.739175e+09
# 908   909                 Susy Mouriz   13000000.0  6.270909e+09
# 970   971                    _vector_   12400000.0  7.597013e+09
# 990   991                Natan por A�   12300000.0  9.029610e+09
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# ...

# %%
print(f"Lower bound: {lower_bound}")
print(f"Upper bound: {upper_bound}")
# Out:
# Lower bound: -50100.0
# Upper bound: 90700.0

# %%
def cap_outliers(data, lower_threshold, upper_threshold):
    capped_data = np.clip(data, lower_threshold, upper_threshold)
    return capped_data

# Cap the outliers
capped_data = cap_outliers(df.lowest_yearly_earnings, lower_bound, upper_bound)
capped_data

df.loc[:,'lowest_monthly_earnings'] = capped_data

# %%
Q1 = np.percentile(df.lowest_monthly_earnings, 25)
Q3 = np.percentile(df.lowest_monthly_earnings, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.lowest_monthly_earnings < lower_bound) | (df.lowest_monthly_earnings > upper_bound)]
outliers
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video_views, category, Title, uploads, Country, channel_type, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days]
# Index: []

# %%
#highest_yearly_earnings

Q1 = np.percentile(df.highest_yearly_earnings, 25)
Q3 = np.percentile(df.highest_yearly_earnings, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.highest_yearly_earnings < lower_bound) | (df.highest_yearly_earnings > upper_bound)]
outliers
# Out:
#      rank                    Youtuber  subscribers   video_views  \
# 0       1                    T-Series   39750000.0  2.745454e+10
# 2       3                     MrBeast   39750000.0  2.745454e+10
# 3       4  Cocomelon - Nursery Rhymes   39750000.0  2.745454e+10
# 4       5                   SET India   39750000.0  2.745454e+10
# 6       7         ��� Kids Diana Show   39750000.0  2.745454e+10
# ..    ...                         ...          ...           ...
# 858   859              Peet Montzingo   13400000.0  1.002256e+10
# 905   906                        GH'S   13000000.0  8.739175e+09
# 908   909                 Susy Mouriz   13000000.0  6.270909e+09
# 970   971                    _vector_   12400000.0  7.597013e+09
# 990   991                Natan por A�   12300000.0  9.029610e+09
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# ...

# %%
print(f"Lower bound: {lower_bound}")
print(f"Upper bound: {upper_bound}")
# Out:
# Lower bound: -9645625.0
# Upper bound: 17467375.0

# %%
def cap_outliers(data, lower_threshold, upper_threshold):
    capped_data = np.clip(data, lower_threshold, upper_threshold)
    return capped_data

# Cap the outliers
capped_data = cap_outliers(df.lowest_yearly_earnings, lower_bound, upper_bound)
capped_data

df.loc[:,'highest_yearly_earnings'] = capped_data

# %%
Q1 = np.percentile(df.highest_yearly_earnings, 25)
Q3 = np.percentile(df.highest_yearly_earnings, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.highest_yearly_earnings < lower_bound) | (df.highest_yearly_earnings > upper_bound)]
outliers
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video_views, category, Title, uploads, Country, channel_type, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days]
# Index: []

# %%
#highest_monthly_earnings

Q1 = np.percentile(df.highest_monthly_earnings, 25)
Q3 = np.percentile(df.highest_monthly_earnings, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.highest_monthly_earnings < lower_bound) | (df.highest_monthly_earnings > upper_bound)]
outliers
# Out:
#      rank                    Youtuber  subscribers   video_views  \
# 0       1                    T-Series   39750000.0  2.745454e+10
# 2       3                     MrBeast   39750000.0  2.745454e+10
# 3       4  Cocomelon - Nursery Rhymes   39750000.0  2.745454e+10
# 4       5                   SET India   39750000.0  2.745454e+10
# 6       7         ��� Kids Diana Show   39750000.0  2.745454e+10
# ..    ...                         ...          ...           ...
# 858   859              Peet Montzingo   13400000.0  1.002256e+10
# 905   906                        GH'S   13000000.0  8.739175e+09
# 908   909                 Susy Mouriz   13000000.0  6.270909e+09
# 970   971                    _vector_   12400000.0  7.597013e+09
# 990   991                Natan por A�   12300000.0  9.029610e+09
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# ...

# %%
print(f"Lower bound: {lower_bound}")
print(f"Upper bound: {upper_bound}")
# Out:
# Lower bound: -801450.0
# Upper bound: 1451750.0

# %%
def cap_outliers(data, lower_threshold, upper_threshold):
    capped_data = np.clip(data, lower_threshold, upper_threshold)
    return capped_data

# Cap the outliers
capped_data = cap_outliers(df.highest_monthly_earnings, lower_bound, upper_bound)
capped_data

df.loc[:,'highest_monthly_earnings'] = capped_data

# %%
Q1 = np.percentile(df.highest_monthly_earnings, 25)
Q3 = np.percentile(df.highest_monthly_earnings, 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df.highest_monthly_earnings < lower_bound) | (df.highest_monthly_earnings > upper_bound)]
outliers
# Out:
# Empty DataFrame
# Columns: [rank, Youtuber, subscribers, video_views, category, Title, uploads, Country, channel_type, video_views_for_the_last_30_days, lowest_monthly_earnings, highest_monthly_earnings, lowest_yearly_earnings, highest_yearly_earnings, subscribers_for_last_30_days]
# Index: []

# %%
x=df[['video_views','lowest_yearly_earnings','lowest_monthly_earnings','highest_yearly_earnings','highest_monthly_earnings']]
x
# Out:
#       video_views  lowest_yearly_earnings  lowest_monthly_earnings  \
# 0    2.745454e+10               1088775.0                  90700.0
# 1    0.000000e+00                     0.0                      0.0
# 2    2.745454e+10               1088775.0                  90700.0
# 3    2.745454e+10               1088775.0                  90700.0
# 4    2.745454e+10               1088775.0                  90700.0
# ..            ...                     ...                      ...
# 990  9.029610e+09               1088775.0                  90700.0
# 991  1.674410e+09                194200.0                  90700.0
# 992  2.214684e+09                   201.0                    201.0
# 993  3.741235e+08                 11600.0                  11600.0
# 994  2.129774e+09                 72000.0                  72000.0
#
#      highest_yearly_earnings  highest_monthly_earnings
# 0                  1088775.0                 1451750.0
# ...

# %%
y = df[['subscribers']]
y
# Out:
#      subscribers
# 0     39750000.0
# 1     39750000.0
# 2     39750000.0
# 3     39750000.0
# 4     39750000.0
# ..           ...
# 990   12300000.0
# 991   12300000.0
# 992   12300000.0
# 993   12300000.0
# 994   12300000.0
#
# [995 rows x 1 columns]

# %%
multiple linear regression
knn classifier
decision tree
random forest
support vector machine
# Out:
#   Input In [54]
#     multiple linear regression
#              ^
# SyntaxError: invalid syntax

# %%
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")

# %% [markdown]
# ### multiple linear regression

# %%
# Create a linear regression model
from sklearn.linear_model import MultipleLinearRegression
lr = MuLinearRegression()
# Fit the model to the training data
lr.fit(X_train, y_train)
# Make predictions on the test data
y_pred = lr.predict(X_test)
# Evaluate the model
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f"R-squared (Coefficient of Determination): {round(r2,2)}")

# %% [markdown]
# ### decision tree

# %%
from sklearn.tree import DecisionTreeRegressor
# Create a Decision Tree model
dt = DecisionTreeRegressor(max_depth = 3)
# Fit the model to the training data
dt.fit(X_train, y_train)
# Make predictions on the test data
y_pred = dt.predict(X_test)
# Evaluate the model
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f"R-squared (Coefficient of Determination): {round(r2,2)}")

# %% [markdown]
# ### random forest

# %%
from sklearn.ensemble import RandomForestRegressor
# Create a linear regression model
rf = RandomForestRegressor(n_estimators=100, random_state=42)
# Fit the model to the training data
rf.fit(X_train, y_train)
# Make predictions on the test data
y_pred = rf.predict(X_test)
# Evaluate the model
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f"R-squared (Coefficient of Determination): {round(r2,2)}")

# %% [markdown]
# ### SVR

# %%
from sklearn.svm import SVR
# Create a SVR regression model
model = SVR(kernel='linear')
# Fit the model to the training data
rf.fit(X_train, y_train)
# Make predictions on the test data
y_pred = rf.predict(X_test)
# Evaluate the model
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f"R-squared (Coefficient of Determination): {round(r2,2)}")

# %% [markdown]
# ### considering every algorithm decision tree  algorithm is considered

# %% [markdown]
# #### make predictions with new data

# %%
x.tail()

# %%
y.tail()

# %%
video_views=9000
lowest_yearly_earnings=201
lowest_monthly_earnings=201
highest_yearly_earnings=201
highest_monthly_earnings=268
y_pred = rf.predict([[video_views,lowest_yearly_earnings,lowest_monthly_earnings,highest_yearly_earnings,highest_monthly_earnings]])
print(f"Predicted Subscribers: {round(y_pred[0])}")
